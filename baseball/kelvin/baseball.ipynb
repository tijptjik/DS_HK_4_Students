# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats
import re

# %%
from numpy import log, array, dot, linalg, nan
from pandas import Series, DataFrame
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from scipy.stats import bernoulli
from scipy.linalg import inv
from sklearn import linear_model, feature_selection, metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.cross_validation import cross_val_score
from math import sqrt, isnan

# %%
# Set some Pandas options
pd.set_option('max_columns', 30)
pd.set_option('max_rows', 20)

# Default Plotting Size
mpl.rc("figure", figsize=(20, 8))

DATA_DIR = 'ds/DS_HK_4/data/'

# %%
# Load the baseball training and test datasets
bbtrain = pd.read_csv(DATA_DIR + 'baseball_training.csv')
bbtest = pd.read_csv(DATA_DIR + 'baseball_test.csv')

# Ensure all values numeric and replace any infinity or NaN values by zero 
bbtrain.convert_objects(convert_numeric=True)
bbtest.convert_objects(convert_numeric=True)

bbtrain = bbtrain.replace([np.inf, -np.inf, np.NaN], float(0))
bbtest = bbtest.replace([np.inf,-np.inf, np.NaN], float(0))

# %%
# define functions
def SSE(pred, resp):
    return mean((pred - resp) ** 2)

def MSE(pred, resp):
    return metrics.mean_squared_error(pred, resp)

def fp_value(x,y):
    feature_selection.univariate_selection.f_regression(x, y)

# %%
# Create sabermetric variables to use as regressors:
# 1."Slugging Percentage" +"On Base Percentage" = "On Base plus Slugging"
slg = lambda x: (x['H_batting']-x['2B']-x['3B']-x['HR_batting'] + 2*x['2B'] + 3*x['3B'] + 4*x['HR_batting'])/(x['AB']+1e-6)
bbtrain['SLG'] = bbtrain.apply(slg, axis=1)
bbtest['SLG'] = bbtest.apply(slg, axis=1)

obp = lambda x: (x['H_batting']+x['BB_batting']+x['HBP_batting'])/(x['AB']+x['BB_batting']+x['HBP_batting']+x['SF_batting']+1e-6) 
bbtrain['OBP'] = bbtrain.apply(obp, axis=1)
bbtest['OBP'] = bbtest.apply(obp, axis=1)

obs = lambda x: x['OBP'] + x['SLG']
bbtrain['OBS'] = bbtrain.apply(obs, axis=1)
bbtest['OBS'] = bbtest.apply(obs, axis=1)

# %%
# 2. "Earned Run Average (ERA) metric, "Innings Pitched" and drop rows where "Innings Pitched"=0
ip = lambda x: x['IPouts']/3
bbtrain['IP'] = bbtrain.apply(ip, axis=1)
bbtrain = bbtrain[bbtrain['IP'] > 0]
bbtest['IP'] = bbtest.apply(ip, axis=1)
bbtest = bbtest[bbtest['IP'] > 0]

# %%
era = lambda x: (9 * (x['ER']/x['IP']))
bbtrain['ERA'] = bbtrain.apply(era, axis=1)
bbtest['ERA'] = bbtest.apply(era, axis=1)

# %%
# 3. "Fielding Independent Pitching (FIP)" metric and its constant
fipc = lambda x: (log(x['ERA'])-(((13*log(x['HR_pitching']))+(3*(log(x['BB_pitching'])+log(x['HBP_pitching'])))-(2*log(x['SO_pitching'])))/log(x['IP'])))
bbtrain['FIPC'] = bbtrain.apply(fipc, axis=1)
bbtest['FIPC'] = bbtest.apply(fipc, axis=1)

fip = lambda x: (x['FIPC'] + (((13*x['HR_pitching'])+(3*(x['BB_pitching']+x['HBP_pitching']))-(2*x['SO_pitching']))/x['IP']))
bbtrain['FIP'] = bbtrain.apply(fip, axis=1)
bbtest['FIP'] = bbtest.apply(fip, axis=1)

bbtrain = bbtrain.replace([np.inf, -np.inf, np.NaN], float(0))
bbtest = bbtest.replace([np.inf,-np.inf, np.NaN], float(0))

# %%
# Drop rows in Salary column with zeros and ensure all entries are float type
bbtrain = bbtrain[bbtrain['salary']>0]
bbtrain['salary'].dtype==float

bbtrain['salary'].isnull()
# Out:
# 0     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 45    False
# 46    False
# ...
# 96650    False
# 96651    False
# 96652    False
# 96701    False
# 96702    False
# 96703    False
# 96704    False
# 96705    False
# Name: salary, Length: 10252, dtype: bool

# %%
# A MultiIndex is created first, so it's easier to refer to rows.
#bbtrain = bbtrain.set_index(['playerID','yearID','teamID'])

# Then function created which checks whether a player has a salary in the previous year. [^1]
#def hasPrevSalary(r):
#    try:
#        prev = bbtrain.xs((r['playerID'], int((r['yearID'] - 1))))['log_salary'].values
#    except:
#        return None
#    if len(prev) == 0:
#        return None
#    else:
#        return prev[0]

# Function applied to each of record in the dataframe. But first index reset so all values available to the function 
# it just looks at values, now the index)
#prev_year_log_salary = bbtrain.reset_index()[['playerID','yearID','teamID','log_salary']].apply(hasPrevSalary, axis=1)

# Reset the index to the original one
#bbtrain.reset_index(inplace=True)

# Add new column
#bbtrain['prev_year_log_salary'] = prev_year_log_salary

#Show the result
#bbtrain[['playerID','yearID','teamID','log_salary','prev_year_log_salary']]

# %% [markdown]
# Useful exercise, but ultimately the previous year salary variable not used, so I commented out the code

# %%
bbtrain.describe()
# Out:
#              yearID     birthYear    birthMonth      birthDay     deathYear  \
# count  10252.000000  10252.000000  10252.000000  10252.000000  10252.000000
# mean    1999.227370   1969.830375      6.781409     15.752048     36.976687
# std        7.688381      8.588263      3.464540      8.799547    269.826296
# min     1985.000000   1939.000000      1.000000      1.000000      0.000000
# 25%     1993.000000   1964.000000      4.000000      8.000000      0.000000
# 50%     1999.000000   1970.000000      7.000000     16.000000      0.000000
# 75%     2006.000000   1976.000000     10.000000     23.000000      0.000000
# max     2012.000000   1990.000000     12.000000     31.000000   2013.000000
#
#          deathMonth      deathDay       weight        height         G_all  \
# count  10252.000000  10252.000000  10252.00000  10252.000000  10252.000000
# mean       0.127097      0.340909    201.12895     74.412212     35.012973
# std        1.019534      2.753728     21.87974      2.110867     21.072176
# min        0.000000      0.000000    150.00000     66.000000      1.000000
# 25%        0.000000      0.000000    185.00000     73.000000     20.000000
# 50%        0.000000      0.000000    200.00000     74.000000     32.000000
# 75%        0.000000      0.000000    215.00000     76.000000     49.000000
# max       12.000000     30.000000    310.00000     83.000000    154.000000
#
#           G_defense           G_p           G_c          G_1b          G_2b  \
# count  10252.000000  10252.000000  10252.000000  10252.000000  10252.000000
# mean      34.685915     33.966055      0.060086      0.085349      0.128268
# std       20.726891     20.256511      2.031625      1.900570      2.970021
# min        1.000000      1.000000      0.000000      0.000000      0.000000
# 25%       19.000000     19.000000      0.000000      0.000000      0.000000
# 50%       32.000000     32.000000      0.000000      0.000000      0.000000
# 75%       48.000000     47.000000      0.000000      0.000000      0.000000
# max      153.000000     94.000000    111.000000     98.000000    118.000000
#
#            ...                 DP             E             A            PO  \
# count      ...       10252.000000  10252.000000  10252.000000  10252.000000
# mean       ...           1.091982      0.868026     13.041065      7.584666
# std        ...           3.005251      1.315970     16.551589     23.540610
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           0.000000      0.000000      4.000000      2.000000
# 50%        ...           0.000000      0.000000      9.000000      4.000000
# 75%        ...           1.000000      1.000000     18.000000      8.000000
# max        ...         113.000000     25.000000    441.000000    649.000000
#
#             InnOuts            GS             G           salary  \
# count  10252.000000  10252.000000  10252.000000     10252.000000
# mean     291.250975     11.128560     34.710788   1652879.007998
# std      288.655523     14.850172     21.767359   2684465.704264
# min        0.000000      0.000000      0.000000     60000.000000
# 25%      121.000000      0.000000     19.000000    230000.000000
# 50%      216.000000      2.000000     32.000000    495000.000000
# 75%      433.250000     23.000000     48.000000   1900000.000000
# max     7188.000000    280.000000    290.000000  24285714.000000
#
#                 SLG           OBP           OBS            IP           ERA  \
# count  10252.000000  10252.000000  10252.000000  10252.000000  10252.000000
# mean       0.085827      0.088147      0.173975     91.140493      4.812111
# std        0.191231      0.162635      0.333571     68.172962      3.509477
# min        0.000000      0.000000      0.000000      0.333333      0.000000
# 25%        0.000000      0.000000      0.000000     39.000000      3.375000
# 50%        0.000000      0.000000      0.000000     71.000000      4.254852
# 75%        0.125000      0.153846      0.285714    140.000000      5.365840
# max        3.999996      1.000000      4.999995    281.666667    108.000000
#
#                FIPC           FIP
# count  10252.000000  10252.000000
# mean      -4.615068     -3.522238
# std        3.012058      2.611148
# min      -11.109628     -8.696671
# 25%       -7.069181     -5.687629
# 50%       -5.615763     -4.253308
# 75%       -1.803406     -0.218868
# max        4.567624     10.714265
#
# [8 rows x 77 columns]

# %%
# Plot salary in a scatterplot
x = [x for x in range(10252)]
y = bbtrain['salary'].values
y.sort()

plt.scatter(x,y,alpha=0.01)
plt.show()

# %%
# Convert salary to log and make histogram
bbtrain['log_salary'] = log(bbtrain['salary'])
bbtrain.hist(column='log_salary',figsize=(5,5),bins=20)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x7fce7ba9bd90>]], dtype=object)

# %%
# Make scatterplot of log salary
z = bbtrain['log_salary'].values
z.sort()

plt.scatter(x,z,alpha=0.01)
plt.show()

# %% [markdown]
# From scatterplot, looks like log salary is better to use as Y-variable

# %%
# Using Statsmodel for linear regression model on sabermetric variables for
# batting, pitching, stolen bases & fielding (putouts, assists, double plays)
X = bbtrain[['OBP','FIP','SB_batting', 'PO', 'A', 'DP']]
Y = bbtrain[['log_salary']]

# Use Seaborn to plot scatterplots of hypothesized X variables & log salary
g = sns.PairGrid(X)
g.map(plt.scatter)

# %% [markdown]
# From scatterplots, it looks like the X-variables mostly appear independent except for 2 fielding statistics - Assists(A) & Double Plays(DP)

# %%
# Using statsmodel to generate an OLS model 
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_salary   R-squared:                       0.666
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     3406.
# Date:                Wed, 14 Jan 2015   Prob (F-statistic):               0.00
# Time:                        04:18:50   Log-Likelihood:                -35580.
# No. Observations:               10252   AIC:                         7.117e+04
# Df Residuals:                   10246   BIC:                         7.122e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# OBP            7.8294      0.480     16.309      0.000         6.888     8.770
# FIP           -1.9652      0.027    -71.499      0.000        -2.019    -1.911
# SB_batting    -0.4136      0.180     -2.298      0.022        -0.766    -0.061
# PO             0.0365      0.005      7.498      0.000         0.027     0.046
# A              0.1136      0.009     13.058      0.000         0.097     0.131
# DP            -0.3171      0.050     -6.373      0.000        -0.415    -0.220
# ==============================================================================
# Omnibus:                      525.966   Durbin-Watson:                   0.796
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              306.491
# Skew:                           0.279   Prob(JB):                     2.79e-67
# Kurtosis:                       2.363   Cond. No.                         179.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The linear regression model generates a fairly high R-squared result, and all the selected X-variables are statistically significant in the training dataset.  This gives me confidence the model should work in predicting 2013 salaries on the test dataset

# %%
# Statsmodel plot to compare the true relationship to OLS predictions with confidence intervals
prstd, iv_l, iv_u = wls_prediction_std(est)

fig, ax = plt.subplots(figsize=(8,6))

ax.plot(x, y, 'o', label="data")
ax.plot(x, y, 'b-', label="True")
ax.plot(x, est.fittedvalues, 'r--.', label="OLS")
ax.plot(x, iv_u, 'r--')
ax.plot(x, iv_l, 'r--')
ax.legend(loc='best');

# %%
# Trying out ridge and polynomial models on training dataset
est1 = Ridge(normalize=True)
poly = PolynomialFeatures(3)

X1 = bbtrain[['OBP','FIP','SB_batting', 'PO', 'A', 'DP']].values
X1 = poly.fit_transform(X)
Y1 = bbtrain['log_salary'].values

# This runs a cross-validated routine (split-->fit--> predict--> score) 
scores = cross_val_score(est1, X1, Y1, cv=10)
np.mean(scores)
# Out:
# -62.642789541769091

# %%
# Using Statsmodel to predict salary in test dataset 
Xtest = bbtest[['OBP','FIP','SB_batting', 'PO', 'A', 'DP']]

ypred = est.predict(Xtest)

# %%
# Put results of salary prediction into new column in test dataset
bbtest['salary_pred'] = ypred
bbtest.head(10)
# Out:
#      playerID  yearID teamID  birthYear  birthMonth  birthDay birthCountry  \
# 0   aardsda01    2013    NYN       1981          12        27          USA
# 1    abadfe01    2013    WAS       1985          12        17         D.R.
# 3   aceveal01    2013    BOS       1982          12         8       Mexico
# 7   adamsmi03    2013    PHI       1978           7        29          USA
# 10  affelje01    2013    SFN       1979           6         6          USA
# 11  alberan01    2013    MIN       1985          10         6          CAN
# 12  alberma01    2013    CLE       1983           1        20          USA
# 13  albural01    2013    DET       1986           6        10         D.R.
# 14  allenco01    2013    CLE       1988          11        20          USA
# 19  alvarhe01    2013    MIA       1990           4        18    Venezuela
#
#               birthState              birthCity  deathYear  deathMonth  \
# 0                     CO                 Denver          0           0
# 1              La Romana              La Romana          0           0
# 3                 Sonora  San Luis Rio Colorado          0           0
# 7                     TX         Corpus Christi          0           0
# 10                    AZ                Phoenix          0           0
# 11                    SK       North Battleford          0           0
# 12                    TX                Houston          0           0
# 13  San Pedro de Macoris   San Pedro de Macoris          0           0
# 14                    FL                Orlando          0           0
# 19              Carabobo               Valencia          0           0
#
#     deathDay  deathCountry  deathState  deathCity    ...     DP  E   A  PO  \
# 0          0             0           0          0    ...      0  0   5   1
# 1          0             0           0          0    ...      0  0   4   1
# 3          0             0           0          0    ...      0  2   7   2
# 7          0             0           0          0    ...      0  1   3   5
# 10         0             0           0          0    ...      0  0   9   1
# 11         0             0           0          0    ...      1  0   9   4
# 12         0             0           0          0    ...      1  1  11   4
# 13         0             0           0          0    ...      0  1   2   4
# 14         0             0           0          0    ...      0  3   5   0
# 19         0             0           0          0    ...      1  1  19  14
#
#     InnOuts  GS   G  SLG       OBP       OBS          IP       ERA      FIPC  \
# 0       119   0  43  0.0  0.000000  0.000000   39.666667  4.310924 -6.994737
# 1       113   0  39  0.0  0.000000  0.000000   37.666667  3.345133 -2.721710
# 3       111   6  11  0.0  0.000000  0.000000   37.000000  4.864865  0.000000
# 7        75   0  28  0.0  0.000000  0.000000   25.000000  3.960000 -5.410408
# 10      101   0  39  0.0  0.000000  0.000000   33.666667  3.742574 -3.110869
# 11      180  10  10  0.0  0.000000  0.000000   60.000000  4.050000 -4.651652
# 12      189   0  56  0.0  0.000000  0.000000   63.000000  3.142857 -1.583888
# 13      147   0  53  0.0  0.000000  0.000000   49.000000  4.591837 -4.921091
# 14      211   0  77  0.0  0.000000  0.000000   70.333333  2.431280 -5.251939
# 19      308  17  17  0.5  0.290323  0.790323  102.666667  3.594156 -2.315659
#
#          FIP  salary_pred
# 0  -4.776249     9.990389
# 1  -2.509320     5.421955
# 3   0.000000     0.867924
# 7  -3.210408     6.832206
# 10 -1.714829     4.428436
# 11 -3.734985     8.190835
# 12 -1.139444     3.317295
# 13 -4.247621     8.720425
# 14 -5.308811    11.000444
# 19 -2.179296     8.907406
#
# [10 rows x 98 columns]

# %%
# Exporting test results to .csv file
bbtest.to_csv(DATA_DIR + 'baseballpredict_kelvin.csv')
